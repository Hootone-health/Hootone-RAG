# %% [markdown]
# # Stage 2: Semantic chunking with Gemma embeddings
#
# This notebook loads local PDFs, converts them into LangChain `Document` objects, and applies semantic chunking using the Gemma embedding model exposed via the local OpenAI-compatible endpoint.
#
# **What you need running**
# - Docker Model Runner exposing embeddings at `http://localhost:12434/engines/v1`
# - Model name: `ai/embeddinggemma`
# - PDFs located at `C:\Users\Admin\Desktop\rag-hootone\data\uploads\PDF`
#
# Adjust the chunking thresholds as needed to tune chunk sizes for your corpus.

# %%
# If needed, install dependencies (uncomment to run in a fresh environment).
# !pip install -q "langchain>=0.2" "langchain-community>=0.2" "langchain-text-splitters>=0.2" "openai>=1.50" "pymupdf" "qdrant-client" "langchain-qdrant"
# use uv add langchain langchain-community langchain-text-splitters openai pymupdf qdrant-client langchain-qdrant

# %%
from __future__ import annotations

import os
from pathlib import Path
from typing import List

from langchain_community.document_loaders import PyMuPDFLoader
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
# from langchain_text_splitters import SemanticChunker
from langchain_experimental.text_splitter import SemanticChunker


# Endpoint/model configuration
MODEL_RUNNER_BASE_URL = os.getenv("MODEL_RUNNER_BASE_URL", "http://localhost:12434/engines/v1")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "docker")
EMBED_MODEL_NAME = "ai/embeddinggemma"

# Data location
PDF_DIR = Path(r"C:\Users\Admin\Desktop\rag-hootone\data\uploads\PDF")

# %%
import re
import unicodedata
import tempfile
import fitz


def _strip_control_chars(text: str) -> str:
    # Remove non-printable control chars excluding common whitespace
    return "".join(ch for ch in text if ch.isprintable() or ch in {"\n", "\t", " "})


def _collapse_whitespace(text: str) -> str:
    # Collapse runs of whitespace and trim per line
    lines = [re.sub(r"\s+", " ", line).strip() for line in text.splitlines()]
    return "\n".join(line for line in lines if line)


class PDFPreprocessor:
    """Clean PDF text and emit a temporary sanitized PDF for downstream loading."""

    def __init__(self, output_dir: Path | None = None):
        # Use a temp directory if none provided
        self.output_dir = Path(output_dir) if output_dir else Path(tempfile.gettempdir()) / "cleaned_pdfs"
        self.output_dir.mkdir(parents=True, exist_ok=True)

    def clean_pdf(self, pdf_path: Path) -> Path:
        """Return path to cleaned PDF copy."""
        cleaned_path = self.output_dir / pdf_path.name
        with fitz.open(pdf_path) as src_doc, fitz.open() as new_doc:
            for page in src_doc:
                text = page.get_text("text")
                text = unicodedata.normalize("NFKC", text)
                text = _strip_control_chars(text)
                text = _collapse_whitespace(text)

                # Preserve page size; place cleaned text in a textbox covering the page
                rect = page.rect
                new_page = new_doc.new_page(width=rect.width, height=rect.height)
                new_page.insert_textbox(rect, text, fontsize=11, fontname="helv")

            new_doc.save(cleaned_path)
        return cleaned_path

# %%
CLEANED_PDF_DIR = PDF_DIR / "cleaned"
CLEANED_PDF_DIR.mkdir(parents=True, exist_ok=True)

pdf_preprocessor = PDFPreprocessor(output_dir=CLEANED_PDF_DIR)

# %% [markdown]
# ### PDF preprocessing steps
# - Normalize Unicode to NFKC to harmonize accents and symbols.
# - Strip control characters while keeping newlines/tabs needed for structure.
# - Collapse repeated whitespace and blank lines to reduce noise.
# - Re-emit a cleaned PDF copy (page sizes preserved) for `PyMuPDFLoader`.

# %% [markdown]
# ## Load PDFs into LangChain Documents
# We load every PDF in the target directory with `PyMuPDFLoader`, which produces LangChain `Document` objects containing both page text and metadata (source path, page number).

# %%
def load_pdfs(pdf_dir: Path, preprocessor: PDFPreprocessor | None = None) -> List[Document]:
    if not pdf_dir.exists():
        raise FileNotFoundError(f"PDF directory not found: {pdf_dir}")

    documents: List[Document] = []
    for pdf_path in sorted(pdf_dir.glob("*.pdf")):
        target_path = preprocessor.clean_pdf(pdf_path) if preprocessor else pdf_path
        loader = PyMuPDFLoader(str(target_path))
        docs = loader.load()
        documents.extend(docs)
    if not documents:
        raise FileNotFoundError(f"No PDFs found in {pdf_dir}")
    return documents

raw_documents = load_pdfs(PDF_DIR, preprocessor=pdf_preprocessor)
print(f"Loaded {len(raw_documents)} pages from {PDF_DIR}")
# Peek at the first document metadata
raw_documents[0]
# Out:
# Loaded 7 pages from C:\Users\Admin\Desktop\rag-hootone\data\uploads\PDF
# Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='REPRESENTATIVES DATA ? TEXT ONLY\nHeadquarters (India)\nName: Hootone Remedies\nAddress: 3A, Pitru Chaya, Beside Mehboob Film Studio, 23C, Hill Road, Bandra (W),\nMumbai, Maharashtra 400050, India.\nPhone: +919594000093\nEmail: info@hootone.org\nNorthern Nigeria\n? Representative Name: Pharm. Kabir Hamza Kankara\n? Address: No. 7, Gabasawa Qtrs, Kwado, Off Mani Road, Katsina, Nigeria.\n? Phone/WhatsApp: +2348036785766\n? Email: kabirkt2003@gmail.com\nSouthern Nigeria\n? Representative Name: Hootone Pharmacy Limited\n? Address: 182 Wetheral Road, Owerri, IMO, Nigeria.\n? Phone: +2348031934323\n? WhatsApp: +2348063322507\n? Email: merchandies@yahoo.com\nGhana\n? Representative Name: Mr. Samuel Buernortey Puplampu\n? Address: VHC/B05/MA, Valco Estate, Mataheko Afienya, Tema, Greater Accra,\nGhana.\n? Phone/WhatsApp: +233245419914\n? Email: samuelpope419@gmail.com\nLiberia')

# %%
raw_documents
# Out:
# [Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='REPRESENTATIVES DATA ? TEXT ONLY\nHeadquarters (India)\nName: Hootone Remedies\nAddress: 3A, Pitru Chaya, Beside Mehboob Film Studio, 23C, Hill Road, Bandra (W),\nMumbai, Maharashtra 400050, India.\nPhone: +919594000093\nEmail: info@hootone.org\nNorthern Nigeria\n? Representative Name: Pharm. Kabir Hamza Kankara\n? Address: No. 7, Gabasawa Qtrs, Kwado, Off Mani Road, Katsina, Nigeria.\n? Phone/WhatsApp: +2348036785766\n? Email: kabirkt2003@gmail.com\nSouthern Nigeria\n? Representative Name: Hootone Pharmacy Limited\n? Address: 182 Wetheral Road, Owerri, IMO, Nigeria.\n? Phone: +2348031934323\n? WhatsApp: +2348063322507\n? Email: merchandies@yahoo.com\nGhana\n? Representative Name: Mr. Samuel Buernortey Puplampu\n? Address: VHC/B05/MA, Valco Estate, Mataheko Afienya, Tema, Greater Accra,\nGhana.\n? Phone/WhatsApp: +233245419914\n? Email: samuelpope419@gmail.com\nLiberia'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='? Representative Name: Dr. Felix Boye Dimaro, MD\n? Address: L&B Memorial Clinics, Opposite Baptist Seminary Gate, RIA Highway,\nMonrovia, Liberia.\n? Phone: +231888589165, +231775577714\n? Email: dimdenyan1@gmail.com\nTanzania\n? Representative Name: Dr. James A. Paul\n? Address: Sinza A, Ujamaa Street #66, Ubungo 16102, Dar es Salaam, Tanzania.\n? Phone/WhatsApp: +255762817648\n? Email: jpmbucha@gmail.com\nCameroon\n? Representative Name: Mr. Simon NANFA (Biologist)\n? Address: 2297 Vallee Bessengue, Boulevard de La Republique, Douala, Cameroon.\n? Phone: +237699858232 / +237676918990\n? Email: simon.nanfa@gmail.com\nEthiopia\n? Representative Name: Mr. Endale Melese Tsegaye\n? Address: Skyline Import and Export PLC, Lemikura Sub City, Woreda 03, Noah Adey\nAbeba Real Estate, 3rd Floor, HN. NRE AA 302, Ethiopia.\n? Phone/WhatsApp: +251911179093\nGuinea\n? Representative Name: TCHEKOUEYEP JEAN MARCELLIN\n? Address: KAPORO MARCHÉ, CONAKRY, REPUBLIC OF GUINEA'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content="? WhatsApp: +224 620 07 43 45\n? Email: marcellintchekoueyep@gmail.com\nHIV KNOWLEDGE BASE ? TEXT ONLY\n(Everything below is exactly your content, without code.)\nHOO-IMM PLUS OD (HIV) Knowledge Base\nIs HIV Curable?\nYes, HIV is curable and HOO-IMM PLUS-OD is designed specifically for that.\nUnlike ARVs that only suppress the virus temporarily, our treatment targets and eliminates\nboth the active virus (HIV RNA) and the hidden viral reservoir (HIV DNA Proviral Load) from\nthe body ? which is the root cause of recurring infection.\nThe full treatment typically takes 10 to 12 months.\nThe process happens in clear stages:\n1. In the first 4?6 weeks, patients usually experience a sharp drop in viral load.\n2. Over the next 3?4 months, CD4 levels rise significantly and immunity improves.\n3. By months 8?10, the HIV Proviral DNA becomes undetectable.\n4. After 10?12 months, most patients test HIV DNA NEGATIVE on the Proviral DNA\nPCR Qualitative Test ? confirming complete clearance.\nThousands of patients have already completed this treatment and now test HIV DNA\nNEGATIVE using Proviral DNA PCR Qualitative Tests, which is the highest level of\nmedical confirmation.\nWhile conventional medicine believes there's ?no cure,? that's based on the limitation\nof ARVs. HOO-IMM PLUS-OD is developed after years of botanical research and\nclinical trials ? and it works differently, using a multi-target approach that modern\nARVs don't provide.\nYou can review real patient reports, lab test results, and detailed medical\nexplanations on our official website: www.functionalhivcure.com.\nHow to order medicine / price?\nHow to Order HOO-IMM PLUS-OD & Start Your Recovery\nThe price of HOO-IMM PLUS-OD is $75 per pack.\nEach pack contains 90 capsules (1-month supply). The recommended treatment duration is\n10 to 12 months.\nHow to Buy (with representative):\nYou can order directly through our authorized representative or agent in your country. Reply\nwith your country name for contact details."),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content="What Makes HOO-IMM PLUS-OD Different?\nThis is not another ARV. It's a GMP-certified, FDA-approved, side-effect-free botanical\nmedicine, developed to functionally cure HIV by removing both the active and hidden virus.\nGet a Free Health Report & Expert Guidance\nWe offer a Free Health Report prepared by our doctors. Share details like current\nsymptoms, date of HIV detection, side effects from ARVs, etc.\nHow to order medicine / price / non-rep country?\nOrder directly from Hootone Remedies.\nThe price is $60 per pack plus shipping (1-month supply, 90 capsules).\nShipping charges apply based on location.\nOrder from: https://hootone.org/product/hooimm-plus-od/\nMy HIV is positive, but not started treatment yet?\nYes, you can absolutely start the treatment with HOO-IMM PLUS-OD even if you haven't\ntaken any ARVs yet.\nStarting early before ARVs often leads to even faster results.\nThe treatment plan (10 to 12 months) will:\n1. Reduce your viral load to undetectable levels.\n2. Boost your CD4 count significantly.\n3. Completely clear the virus from your system, confirmed by the Proviral DNA PCR\nQualitative Test.\nThis treatment is plant-based, safe, and free from the long-term side effects\nassociated with ARVs.\nWho are you?\nAbu Salih from Hootone Remedies (Mumbai, India). A leading pharmaceutical firm with ISO\n9001:2000 certification, specializing in Unani, Ayurvedic, and Siddha medicine.\nRepresentatives in Nigeria, Liberia, Ghana, Ethiopia, Tanzania and Serving 55+ Countries\nWorldwide.\nAre There Any Side Effects?\nHOO-IMM PLUS-OD is a 100% plant-based and botanical medicine, completely safe for\nlong-term use. No toxic or long-term side effects.\nCan I Take This With My Other Medications (including ARVs)?\nYes, HOO-IMM PLUS-OD is a natural, plant-based formula and can be taken alongside\ncurrent ARV therapy. Many patients use it to improve their CD4 count and reduce side\neffects from ARVs.\nIt is important to inform doctors about all medications during the free consultation.\nDiet & Lifestyle During Treatment\nEat a balanced diet, avoid alcohol, smoking, and pork. Exercise regularly and rest well."),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content='How Do I Take HOO-IMM PLUS-OD?\n90 capsules per pack.\nDosage: 3 capsules once a day after dinner.\nWhat Happens After My Proviral DNA Test is NEGATIVE?\nIt confirms complete virus clearance. Main treatment course is complete. A post-treatment\nwellness plan will be provided.\nIs My Order & Personal Information Kept Private?\nYes, completely private and discreet.\nSuccess Rate\nThousands of patients now test HIV DNA Negative. No virologic failure reported.\nIs one bottle enough?\nNo. Treatment requires several months (6?12 months).\nWill the virus come back?\nNot after completing the full treatment properly.\nHBV KNOWLEDGE BASE ? TEXT ONLY\n(Complete content preserved exactly.)\nHOO-IMM PLUS B (HBV) Knowledge Base\nIs it really curable?\nYes, complete recovery from Hepatitis B is possible.\nHOO-IMM PLUS B helps patients eliminate HBV DNA. Within 4-6 months, viral load\nbecomes undetectable. Over 10-12 months, most patients test HBsAg Negative and develop\nprotective anti-HBs antibodies (>10 IU/L).\nMedical records: https://curehbv.com/medical-records\nDiscussing health with doctors\nWe offer a free consultation. Share health reports and questions. Our medical team will\nreview and guide you.\nEradicating the virus\nTotal eradication is possible with the right approach.\nOur FDA GMP-manufactured treatment is designed to eliminate HBV DNA, test Negative for\nHBV DNA PCR Qualitative and HBsAg, and boost anti-HBs antibodies.\nI already tried many other treatments\nConventional treatments like Tenofovir only suppress the virus temporarily.\nHOO-IMM PLUS B targets HBV DNA replication, converts HBsAg negative, boosts\nimmunity.'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content='I have HBV Positive but no symptoms\nEven without symptoms, liver damage can happen silently.\nShare tests like HBV DNA viral load, HBsAg, LFT, Anti-HBs antibody.\nWhat tests to do?\nHBV DNA Quantitative\nHBsAg\nAnti-HBs\nLFT\nDiet\nEat fruits, greens, protein; avoid alcohol, oily food, red meat, soft drinks, painkillers.\nDosage\n2 capsules before breakfast\n2 before lunch\n2 before dinner\nHow does it work?\nMonth 1?2: Reduces inflammation\nMonth 4?6: Viral load undetectable\nMonth 10?12: HBsAg non-reactive\nCost\n$85 per pack (180 capsules, 1 month).\nOrder online or from local representatives.\nLocation\nMain factory India.\nOrder at https://hootone.org/product/hoo-imm-plus-b/\nI don?t have reports\nWe check symptoms if reports are unavailable.\nPayment\nWorldwide shipping available.\nAccepts card, bank transfer, UPI, Western Union, Moneygram, RIA.\nReceiver: Mr. SAYYED ASHRAF, HOOTONE REMEDIES, D/58, MEK Industrial Complex,\nMumbra.\nMedicine costly?\nIt focuses on complete eradication.\nMost patients become undetectable within 4?6 months.\nIs it approved?\nProduced under FDA-GMP and ISO 9001:2000.\nCan I take with Tenofovir?\nYes, maintain a 2-hour gap.\nAfter 3 months, Tenofovir can be stopped.'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 6}, page_content='My result is undetectable\nInactive phase but still needs monitoring.\nDrug resistance?\nNo, because it eliminates viral assembly.\nChildren?\nSafe for all ages.\nCan I become HBsAg negative forever?\nYes, many patients achieve this.\nHepatitis C\nAlso recommended for HCV.\nClears virus in 3?4 months, full course 6 months.\nReply to patient reports\nHBV DNA NOT DETECTED: Good\nHBV DNA DETECTED: Start treatment\nHBsAg Positive + DNA Not Detected: Virus still present\nHBsAg Positive + DNA Positive: Active infection\nCost (rep country)\n$85 per month\nTimeline:\n3?4 months: VL drops\n6?8 months: Undetectable\n10?12 months: PCR qualitative negative\n12?15 months: HBsAg negative\nCost (no rep)\nSame cost, worldwide shipping.\nAfter sending report\nDoctors provide a personalized plan.\nPatient usage\nUsed by thousands in 30+ countries.\nCurability\nPositive results in all patients; varies per individual.\nSafety\n100% plant-based, no side effects, FDA-GMP certified.\nHBV Testimonials\nAvailable at https://curehbv.com/medical-records/')]

# %% [markdown]
# ## Semantic chunking with Gemma embeddings
# `SemanticChunker` uses the embedding model to find natural breakpoints. Tune the thresholds to trade off chunk granularity vs. coherence.

# %%
# Adjust this percentile to control chunk granularity.
# Lower values -> more/smaller chunks; higher values -> fewer/larger chunks.
BREAKPOINT_PERCENTILE = 75

embedding_model = OpenAIEmbeddings(
    model=EMBED_MODEL_NAME,
    base_url=MODEL_RUNNER_BASE_URL,
    api_key=OPENAI_API_KEY,
)

chunker = SemanticChunker(
    embedding_model,
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=BREAKPOINT_PERCENTILE,
)

# %%
chunked_documents = chunker.split_documents(raw_documents)

print(f"Chunks created: {len(chunked_documents)}")

# Basic stats
lengths = [len(doc.page_content) for doc in chunked_documents]
print(
    f"Mean length: {sum(lengths)/len(lengths):.1f} chars | "
    f"Min: {min(lengths)} | Max: {max(lengths)}"
)

# Preview a sample chunk
sample_idx = min(3, len(chunked_documents) - 1)
chunked_documents[sample_idx]
# Out:
# Chunks created: 50
# Mean length: 193.0 chars | Min: 1 | Max: 1012
# Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'file_path': 'C:\\Users\\Admin\\Desktop\\rag-hootone\\data\\uploads\\PDF\\cleaned\\Data[1].pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Phone/WhatsApp: +2348036785766\n? Email: kabirkt2003@gmail.com\nSouthern Nigeria\n? Representative Name: Hootone Pharmacy Limited\n?')

# %% [markdown]
# ## Persist chunks to Qdrant
# Use the running Qdrant instance (see `docker-compose.yml`) to store the semantic chunks. The collection name is `rag-hootone`.

# %%
from qdrant_client import QdrantClient
from langchain_qdrant import QdrantVectorStore

QDRANT_URL = os.getenv("QDRANT_URL", "http://localhost:6333")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")  # leave unset if not configured
QDRANT_COLLECTION = "rag-hootone"

client = QdrantClient(url=QDRANT_URL, api_key=QDRANT_API_KEY)

vector_store = QdrantVectorStore.from_documents(
    documents=chunked_documents,
    embedding=embedding_model,
    url=QDRANT_URL,
    api_key=QDRANT_API_KEY,
    collection_name=QDRANT_COLLECTION,
    prefer_grpc=False, # switch to True if using gRPC at 6334, if you want to use HTTP then keep it False
) 

print(f"Upserted {len(chunked_documents)} chunks into Qdrant collection '{QDRANT_COLLECTION}' at {QDRANT_URL}")
# Out:
# Upserted 50 chunks into Qdrant collection 'rag-hootone' at http://localhost:6333

# %% [markdown]
# ## Next steps
# - Adjust `BREAKPOINT_PERCENTILE` (e.g., 85–98) if chunks are too small or too large.
# - Persist `chunked_documents` to your vector store of choice (e.g., Chroma, PGVector, LanceDB) using the same `embedding_model` for consistency.
# - Incorporate these chunks into your retrieval pipeline and LLM workflow.
